# %%
import seaborn as sns
df = pd.read_csv('D:\geekbrains\PYTHON для аналитиков\DZ2\kc_house_data.csv', encoding = 'latin-1')
df.head(20)
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000   221900.0         3       1.00         1180
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 2   5631500400  20150225T000000   180000.0         2       1.00          770
# 3   2487200875  20141209T000000   604000.0         4       3.00         1960
# 4   1954400510  20150218T000000   510000.0         3       2.00         1680
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# 10  1736800520  20150403T000000   662500.0         3       2.50         3560
# ...

# %% [markdown]
# ## Задача 1

# %%
plt.hist(df['price'])
plt.xlabel('млн.USD')
plt.ylabel('количество квартир')
plt.title('цены на квартиры')
# Out:
# Text(0.5, 1.0, 'цены на квартиры')

# %% [markdown]
# наибольшее число квартир лежат в ценовом диопазоне до 1.5 млн USD. стоимость некоторых доходит почти до 4млн.USD

# %%
plt.hist(df['sqft_living'])
plt.xlabel('кв.м')
plt.ylabel('количество квартир')
plt.title('жилая площадь')
# Out:
# Text(0.5, 1.0, 'жилая площадь')

# %%
самое большое число домов занимают от 1.5 до 2.5 тысяч квадратных метров. 7000 домов занимают меньше 1500 кв.метров.
Немногие достигают 8000кв.метров

# %%
plt.hist(df['yr_built'])
plt.xlabel('год')
plt.ylabel('количество квартир')
plt.title('год постройки')
# Out:
# Text(0.5, 1.0, 'год постройки')

# %%
наибольшее число квартир современные - построены после 2000года, но есть и несколько тысяч домов построенных в довоенные 
годы в период  с 1900 до 1940 года.

# %% [markdown]
# ## Задача 2

# %% [markdown]
# ## 2.1  распределение домов от наличия вида на набережную

# %%
data = df['view'].value_counts()
data
# Out:
# 0    19489
# 2      963
# 3      510
# 1      332
# 4      319
# Name: view, dtype: int64

# %%
plt.pie(data.values,labels=data.index,autopct ='%1.2f%%')
plt.legend(data.index);

# %%
больше 90% домов не имеют вида на море.около 5% имеют их 2 .

# %% [markdown]
# ## 2.2 распределение этажей домов

# %%
data = df['floors'].value_counts()
plt.bar(data.index,data.values);

# %%
больше всего 1 и 2-этажных домов. 
поскольку этажность не сильно много показателей имеет, то 
можно использовать круговую диаграмму:

# %%
data = df['floors'].value_counts()
data
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
plt.pie(data.values,labels=data.index,autopct ='%1.2f%%')
plt.legend(data.index);

# %%
эта диаграмма более наглядная : половина домов 1-этажные. почти 40% 2-этажные дома.

# %% [markdown]
# ## 2.3  распределение состояния домов

# %%
data = df['grade'].value_counts()
plt.bar(data.index,data.values);

# %%
большинство домов имеют 7-8 бальное состояние.

# %% [markdown]
# ### ЗАДАЧА 3

# %%
sns.jointplot(x=df['price'],y=df['sqft_living'])

# %%
sns.boxplot(x=df['price'],y=df['bedrooms'],showfliers=False)
# Out:
# <Axes: xlabel='price', ylabel='bedrooms'>

# %%
sns.boxplot(x=df['view'],y=df['price'],showfliers=False)

# %%
sns.boxplot(x=df['price'],y=df['yr_built']showfliers=False)

# %%
sns.boxplot(x=df['price'],y=df['floors'],showfliers=False)

# %%
corr_matrix=df.corr()
corr_matrix=np.round(corr_matrix,1)
corr_matrix

# %%
sns.heatmap(corr_matrix, annot=True)
